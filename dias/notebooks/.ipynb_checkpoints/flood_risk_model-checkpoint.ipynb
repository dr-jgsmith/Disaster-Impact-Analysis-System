# %%
from dias.scripts.flood_model import *
import matplotlib.pyplot as plt

"""
This begins the example use case of value_impact_analysis

"""
# Begin with dBase file commonly associated with attribute data for annotating layers in a GIS
file = "C:\\Users\\justi\\Desktop\\Ab_Hoq_Cosi_Parcels_Lat_Long_Points\\Ab_Hoq_Cosi_Parcels_Lat_Long_Critical_Facilities_NEHRP.dbf"
# Open the file and intitialize the flood model class
db = flood_model(file, 'AIzaSyBWEqdC3EjiDzljsSvJi3v6wUWNKQZAl_g')

# %%
# Define the column or id names
# These will be hard coded and should not be allowed to change
lat = 'Lat'
lon = 'Long'
building_value_field = 'BLDGVALUE'
land_value_field = 'LANDVALUE'
parcel_field = 'PARCELATT'
# Define a new field, Elevation
elevation_field = 'Elevation'

# %%
# Model Parameters can change and these will be used for running simulations and for building some of the base layers.
# Define parameters
# The threshold parameter relates to flood water level in feet
max_impact = 15
impact_range = (5, 14)
# bloss_fun is the percent of value lost on building that has been effected by flood waters.
# This number can be modified. Or could be random within a range based on available data.
building_loss_fun = 0.07
# lloss_fun is the percent of value lost on actual land.
# In a dynamical system, this might be dependent on frequency of events
land_loss_fun = 0.002
# define a set of start points, these are parcels that would likely see the first impacts this allows for points to
# be defined close to bodies of water as well as points where infrastructure fails to accommodate flow.
disturbance_points = ['517100221020', '026800000101']

# %%
data = db.build_base_model(parcel_field, building_value_field, land_value_field, lat, lon, elevation_field)
risk_zones = db.build_risk_layers(data, max_impact)
print("Model Constructed...")
print(len(data[1]))
# Out:
# Building Base Model Layer...
# Building Effect-Connected Layers...
# Effected layers computed...
# Model Constructed...
# 2

# %%
brisk_zones = db.binarize_risk_layers(data[1], risk_zones)
print(brisk_zones)
# Out:
# [array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 1., 1., 0.]), array([0., 0., 0., ..., 1., 1., 0.]), array([0., 0., 0., ..., 1., 1., 1.]), array([0., 0., 0., ..., 1., 1., 1.]), array([0., 0., 0., ..., 1., 1., 1.]), array([0., 0., 0., ..., 1., 1., 1.]), array([0., 1., 0., ..., 1., 1., 1.]), array([0., 1., 1., ..., 1., 1., 1.]), array([0., 1., 1., ..., 1., 1., 1.]), array([0., 1., 1., ..., 1., 1., 1.]), array([0., 1., 1., ..., 1., 1., 1.]), array([0., 1., 1., ..., 1., 1., 1.])]

# %%
impact_intensity = db.compute_impact_intensity(data[4][1], brisk_zones, building_loss_fun)
print(impact_intensity)
# Out:
# ([array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0., 0., 0., ..., 0., 0., 0.]), array([0.        , 0.        , 0.        , ..., 0.52783197, 0.52312404,
#        0.        ]), array([0.        , 0.        , 0.        , ..., 0.45783197, 0.45312404,
#        0.        ]), array([0.        , 0.        , 0.        , ..., 0.38783197, 0.38312404,
#        0.23607662]), array([0.        , 0.        , 0.        , ..., 0.31783197, 0.31312404,
#        0.16607662]), array([0.        , 0.        , 0.        , ..., 0.24783197, 0.24312404,
#        0.09607662]), array([0.        , 0.        , 0.        , ..., 0.17783197, 0.17312404,
#        0.02607662]), array([0.        , 0.00338723, 0.        , ..., 0.10783197, 0.10312404,
#        0.04392338]), array([0.        , 0.06661277, 0.10766734, ..., 0.03783197, 0.03312404,
#        0.11392338]), array([0.        , 0.13661277, 0.03766734, ..., 0.03216803, 0.03687596,
#        0.18392338]), array([0.        , 0.20661277, 0.03233266, ..., 0.10216803, 0.10687596,
#        0.25392338]), array([0.        , 0.27661277, 0.10233266, ..., 0.17216803, 0.17687596,
#        0.32392338]), array([0.        , 0.34661277, 0.17233266, ..., 0.24216803, 0.24687596,
#        0.39392338])], [0, 0, 34, 68, 95, 95, 91, 91, 97, 244, 588, 1268, 1676, 1880, 2089], [1.9171979608024432e-05, 5.447524853316004e-05, 0.005322740198781863, 0.017297144525933745, 0.023952440363949435, 0.028969488756663754, 0.0288728268600066, 0.029579111484219416, 0.03378433455042591, 0.05688784363594357, 0.09512900511999048, 0.16701442482224702, 0.22934905369437494, 0.28146712310914124, 0.33932906674832386])

# %%
plt.plot(impact_intensity[0])
plt.ylabel('Impact Intensity')
plt.show()

# %%
for i in impact_intensity[0]:
    plt.plot(i)
    plt.ylabel('Impact Intensity')
    plt.show()

# %%
plt.plot(impact_intensity[1])
plt.ylabel('Impact Intensity - Sum of Impacts')
plt.show()

# %%
plt.plot(impact_intensity[2])
plt.ylabel('Impact Intensity - Mean of Impact Multiplier')
plt.show()

# %%
print('Initializing simulation...')
values = db.run_model_s(data, risk_zones, impact_range, disturbance_points, bloss_value=building_loss_fun, lloss_value=land_loss_fun,
                        ngrowth=0.04, time_step=20)
print("Model Computed...")
# Out:
# Initializing simulation...
# Running simulation...
# Simulation complete...
# Model Computed...

# %%
new_values = db.run_model_d(data, brisk_zones, bloss_value=building_loss_fun, lloss_value=land_loss_fun)

cfs = db.get_critical_zones('Crit_Facil', 9)
facilities = db.get_critical_facilities('Crit_Facil')

print(cfs)
# Out:
# Running simulation...
# Simulation complete...
# [(0.0, 'Old Landfill'), (0.0, 'Division St.  Pump Station'), (0.0, 'Old Endresen Pump Station/Little Hoq. River Park'), (0.0, 'Hoquiam Lions Park'), (0.0, 'John Gable Field'), (0.0, 'Cottage Ave. Pump Station/Park'), (0.0, 'Cemetery'), (0.0, 'Queen Ave. Pump Station'), (0.0, 'Beacon Hill Tank'), (0.0, 'Pump Station #16'), (0.0, 'Pump Station #10'), (0.0, 'Fairview Reservoirs'), (14.0, 'Pump Station #7'), (0.0, 'Pump Station #14'), (0.0, 'North Aberdeen Water Tank & Radio Tower'), (0.0, 'College Hill Pump Station/Telemetry Bldg.'), (1.0, 'Ramer Ave. Pump Station'), (0.0, 'Elton Bennett Park'), (1.0, 'Richkey Park'), (0.0, 'Pump Station #6'), (2.0, 'Pump Station #5'), (0.0, 'Waste Water Treatment Plant'), (1.0, 'Central Playfield'), (0.0, 'Adams St. Pump Station'), (0.0, 'Library'), (0.0, 'Veterans Park'), (0.0, 'Bayview Ave. Pump Station'), (0.0, 'City Rental Buildings'), (0.0, 'Fire Station - Main'), (0.0, 'Train Station'), (0.0, 'K St. Pump Station'), (0.0, 'Beacon Hill Reservoir/Tennis Court'), (1.0, 'Polson Museum'), (1.0, 'Johnny Green Dike'), (1.0, 'Riverside Ave. Pump Station'), (1.0, 'Police Department'), (1.0, 'Farmers Market'), (1.0, 'Rayonier Point Park'), (22.0, 'Fire Station - Eastside'), (0.0, 'Olympic Stadium'), (0.0, 'Think-of-Me Hill Radio Tower'), (0.0, 'Aberdeen Community Food Bank'), (0.0, 'Armory Building'), (24.0, 'Rotary Log Pavilion'), (0.0, 'Police Station'), (2.0, 'Kansas Street Pump Station'), (0.0, 'Emergency Coordination Center (City Hall)'), (2.0, 'Pump Station #4'), (0.0, 'Faith House Church Food Bank'), (0.0, 'Salvation Army Food Bank'), (0.0, 'AHAB Siren - H Street'), (25.0, 'Pump Station #2'), (0.0, 'Grays Harbor County Juvenile Detention Center'), (22.0, 'Ontario Park'), (22.0, '28th St. Pump Station'), (0.0, 'AHAB Siren - Duffy Street Pump Station'), (0.0, 'Fry Creek Pump Station'), (28.0, 'Pump Station #13'), (0.0, 'Vactor Dump Site'), (0.0, 'Central Fire Station'), (0.0, 'Lincoln Street Pump Station'), (0.0, 'Street/Water Shop - Antenna/Division St. Pump St.'), (0.0, 'Lawrence Street Pump Station'), (25.0, 'AHAB Siren - Pioneer Park'), (0.0, 'Aberdeen Wastewater Treatment Plant'), (25.0, 'Front Street Pump Station'), (25.0, 'Fordney Street Pump Station'), (0.0, 'Pump Station #3'), (25.0, 'Farragut Street Pump Station'), (25.0, 'Pump Station #8'), (25.0, 'Pump Station #9'), (25.0, 'KWOK/KXRO Radio Tower'), (0.0, 'KBKW Radio Tower')]

# %%
output = db.summarize_total_impact(start=0, stop=10)
print(output)
# Out:
# 2121845550.0 <class 'numpy.float64'>
# 2184381316.34 <class 'numpy.float64'>
# 1926432937.6208603 <class 'numpy.float64'>
# 1981162132.4206913 <class 'numpy.float64'>
# 1981162132.4206913 <class 'numpy.float64'>
# 2310234857.556988 <class 'numpy.float64'>
# 2310234857.556988 <class 'numpy.float64'>
# 2380289800.1291895 <class 'numpy.float64'>
# -532906223.87202024 <class 'numpy.float64'>
# 29450859541.819477 <class 'numpy.float64'>
# [2121845550.0, 2184381316.34, 1926432937.6208603, 1981162132.4206913, 1981162132.4206913, 2310234857.556988, 2310234857.556988, 2380289800.1291895, -532906223.87202024, 29450859541.819477]

# %%
output = db.summarize_building_impact(start=0, stop=10)
print(output)

# %%
output = db.summarize_land_impact(start=0, stop=10)
print(output)
